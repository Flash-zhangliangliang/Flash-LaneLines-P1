# %%
# 引入我自己的函数包
# import my packages
import LaneFindingPipline.LaneFinding as lf

# %%
# 引入其他的包
# impot other packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
# 读取图片
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %%
# 灰度转换
# gray scale transform
image_gray = lf.gray_scale(image)

plt.imshow(image_gray)
mpimg.imsave('process_images/solidWhiteRight_gray.jpg', image_gray)

# %%
# 高斯滤波
# Applies a Gaussian Noise kernel
kernel_size = 3
image_gauss = lf.gaussian_blur(image_gray, kernel_size)

plt.imshow(image_gauss)
mpimg.imsave('process_images/solidWhiteRight_gauss.jpg', image_gauss)

# %%
# 边缘检测
# Applies the Canny transform
low_threshold = 50
high_threshold = 150
image_canny = lf.canny(image_gauss, low_threshold, high_threshold)

plt.imshow(image_canny)
mpimg.imsave('process_images/solidWhiteRight_canny.jpg', image_canny)

# %%
# 区域检测
# Applies an image mask.
imshape = image_canny.shape
vertices = np.array([[(0, imshape[0]),(460, 325), (520, 325), (imshape[1], imshape[0])]], dtype=np.int32)
image_interest = lf.region_of_interest(image_canny, vertices)

plt.imshow(image_interest)
mpimg.imsave('process_images/solidWhiteRight_interest.jpg', image_interest)

# %%
# 霍夫变换
# Hough transform
image_hough = lf.hough_lines(image_interest, rho = 1, theta = np.pi / 180, threshold = 15, min_line_len  = 40, max_line_gap = 20)

plt.imshow(image_hough)
mpimg.imsave('process_images/solidWhiteRight_hough.jpg', image_hough)

# %%
image_res = lf.weighted_img(image_hough, image, 0.8, 1, 0)

plt.imshow(image_res)
mpimg.imsave('process_images/solidWhiteRight_weighted.jpg', image_hough)

# %%
# 图片处理管道
# image pip line
image_res = lf.process_image(image)

plt.imshow(image_res)
mpimg.imsave('test_images_output/solidWhiteRight.jpg', image_res)

# %%
#处理其他的图片
# other images
image = mpimg.imread('test_images/solidWhiteCurve.jpg')

image_res = lf.process_image(image)

plt.imshow(image_res)
mpimg.imsave('test_images_output/solidWhiteCurve.jpg', image_res)

# %%
image = mpimg.imread('test_images/solidYellowCurve.jpg')

image_res = lf.process_image(image)

plt.imshow(image_res)
mpimg.imsave('test_images_output/solidYellowCurve.jpg', image_res)

# %%
image = mpimg.imread('test_images/solidYellowCurve2.jpg')

image_res = lf.process_image(image)

plt.imshow(image_res)
mpimg.imsave('test_images_output/solidYellowCurve2.jpg', image_res)

# %%
image = mpimg.imread('test_images/whiteCarLaneSwitch.jpg')

image_res = lf.process_image(image)

plt.imshow(image_res)
mpimg.imsave('test_images_output/whiteCarLaneSwitch.jpg', image_res)

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(lf.process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
# 100%|███████████████████████████████████████████████████████████████████████████████▋| 221/222 [00:06<00:00, 33.31it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
#
# Wall time: 7.61 s

# %%
# %time lf.process_video('test_videos/solidYellowLeft.mp4', 'test_videos_output/solidYellowLeft.mp4')
# Out:
# [MoviePy] >>>> Building video test_videos_output/solidYellowLeft.mp4
# [MoviePy] Writing video test_videos_output/solidYellowLeft.mp4
# 100%|███████████████████████████████████████████████████████████████████████████████▉| 681/682 [00:19<00:00, 32.67it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidYellowLeft.mp4
#
# Wall time: 21.9 s
